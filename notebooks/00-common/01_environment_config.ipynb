# %%
# ============================================================
# ENVIRONMENT CONFIG — LOCAL EXECUTION
# ============================================================

import os
from pyspark.sql import SparkSession

# %%
# -----------------------------------------
# 1. Project Root
# -----------------------------------------
PROJECT_ROOT = "/Users/manoharazalki/F1-ANALYTICS"

# %%
# -----------------------------------------
# 2. Data Paths
# -----------------------------------------
DATA_ROOT        = f"{PROJECT_ROOT}/data"
BRONZE_LANDING   = f"{DATA_ROOT}/bronze/landing"
BRONZE_ROOT      = f"{DATA_ROOT}/bronze"
SILVER_ROOT      = f"{DATA_ROOT}/silver"
GOLD_ROOT        = f"{DATA_ROOT}/gold"
CONTROL_ROOT     = f"{DATA_ROOT}/control"

# %%
# -----------------------------------------
# 3. Create Spark Session
# -----------------------------------------
spark = (
    SparkSession.builder
        .appName("F1-Analytics-Local")
        .master("local[*]")
        .getOrCreate()
)

print("✔ Spark Session Initialized")
print("✔ Environment Config Loaded")
print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/06/08 20:59:22 WARN Utils: Your hostname, Manohars-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.68.78.178 instead (on interface en0)
# 26/06/08 20:59:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/08 20:59:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ✔ Spark Session Initialized
# ✔ Environment Config Loaded
# PROJECT_ROOT: /Users/manoharazalki/F1-ANALYTICS
