# %%
# ============================================================
# BRONZE HELPERS — LOCAL EXECUTION
# ============================================================

from pyspark.sql import functions as F

def add_ingestion_metadata(df, source_path: str):
    """
    Adds ingestion timestamp + source file path manually.
    """
    return (
        df.withColumn("ingest_timestamp", F.current_timestamp())
          .withColumn("source_file", F.lit(source_path))
    )

print("✔ Bronze helper functions loaded")
# Out:
# ✔ Bronze helper functions loaded
