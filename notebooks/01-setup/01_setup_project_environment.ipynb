# %%
# ============================================================
# SETUP PROJECT ENVIRONMENT — LOCAL EXECUTION
# ============================================================

import os

# %%
# -----------------------------------------
# 1. IMPORT ENVIRONMENT CONFIG IF NOT LOADED
# -----------------------------------------
try:
    PROJECT_ROOT
except NameError:
    # Load environment config notebook
    # %run "../00-common/01_environment_config.ipynb"
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/08 21:04:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ✔ Spark Session Initialized
# ✔ Environment Config Loaded
# PROJECT_ROOT: /Users/manoharazalki/F1-ANALYTICS

# %%
# -----------------------------------------
# 2. Ensure folders exist
# -----------------------------------------
folders = [
    BRONZE_LANDING,
    BRONZE_ROOT,
    SILVER_ROOT,
    GOLD_ROOT,
    CONTROL_ROOT
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✔ Ensured folder exists: {folder}")

print("✔ Project environment setup complete")
# Out:
# ✔ Ensured folder exists: /Users/manoharazalki/F1-ANALYTICS/data/bronze/landing
# ✔ Ensured folder exists: /Users/manoharazalki/F1-ANALYTICS/data/bronze
# ✔ Ensured folder exists: /Users/manoharazalki/F1-ANALYTICS/data/silver
# ✔ Ensured folder exists: /Users/manoharazalki/F1-ANALYTICS/data/gold
# ✔ Ensured folder exists: /Users/manoharazalki/F1-ANALYTICS/data/control
# ✔ Project environment setup complete
